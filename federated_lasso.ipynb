# %% [markdown]
# # Final Project Reports
# ## Part A: individual model for each node

# %% [markdown]
# ### Stopping criterion for model
# I use 1e-6 stoping criterion here. This is normal and consistant with global model. And I also tried 1e-5, 1e-4 and 1e-3, all of that did not change the model perfomance largely. Stopping criterion is not very sensitive in this case.

# %% [markdown]
# ### Tune lambda and training for node1

# %%
from lasso_analysis_runner import analyze_single_node, create_summary_visualizations

result1 = analyze_single_node(node_idx=0, data_file="regression_data_node1.csv")
# Out:
# Analyzing Node 1: regression_data_node1.csv
# Training set size: 160, Validation set size: 40
# Starting λ parameter tuning:
# Best λ value: 232.995181 (Validation loss: 66.887720)
#
# Training final model with best λ=232.995181
# Number of non-zero coefficients: 23
#  Non-zero coefficient indices:
#  [85, 123, 126, 229, 232, 249, 299, 305, 322, 360, 362, 399, 429, 447, 461, 491, 493, 500, 514, 526, 546, 559, 587]
# Test loss: 83.915862
#
# Node 1 analysis completed!

# %% [markdown]
# ### Tune lambda and training for node2

# %%
result2 = analyze_single_node(node_idx=1, data_file="regression_data_node2.csv")
# Out:
# Analyzing Node 2: regression_data_node2.csv
# Training set size: 240, Validation set size: 60
# Starting λ parameter tuning:
# Best λ value: 75.431201 (Validation loss: 77.293428)
#
# Training final model with best λ=75.431201
# Number of non-zero coefficients: 130
#  Non-zero coefficient indices:
#  [3, 4, 6, 8, 14, 18, 26, 34, 35, 36, 40, 52, 61, 65, 71, 77, 78, 80, 90, 92, 93, 94, 97, 98, 104, 109, 111, 116, 117, 118, 123, 125, 130, 135, 144, 148, 153, 165, 173, 182, 204, 206, 210, 212, 218, 223, 227, 231, 237, 249, 266, 268, 269, 281, 285, 289, 294, 299, 302, 304, 305, 306, 307, 311, 315, 321, 324, 329, 333, 345, 350, 351, 356, 360, 362, 369, 391, 399, 400, 411, 412, 413, 423, 425, 430, 431, 440, 442, 443, 445, 447, 457, 461, 470, 471, 473, 474, 475, 479, 491, 492, 493, 500, 503, 509, 519, 521, 524, 526, 537, 538, 539, 541, 545, 547, 550, 552, 558, 559, 566, 569, 576, 577, 578, 581, 583, 584, 587, 589, 594]
# Test loss: 115.740839
#
# Node 2 analysis completed!

# %% [markdown]
# ### Tune lambda and training for node3

# %%
result3 = analyze_single_node(node_idx=2, data_file="regression_data_node3.csv")
# Out:
# Analyzing Node 3: regression_data_node3.csv
# Training set size: 400, Validation set size: 100
# Starting λ parameter tuning:
# Best λ value: 109.854114 (Validation loss: 33.806052)
#
# Training final model with best λ=109.854114
# Number of non-zero coefficients: 130
#  Non-zero coefficient indices:
#  [6, 9, 13, 14, 18, 25, 34, 40, 42, 63, 66, 68, 71, 73, 76, 77, 79, 82, 85, 91, 92, 102, 107, 117, 119, 123, 124, 125, 126, 130, 133, 134, 147, 159, 161, 169, 170, 171, 179, 181, 182, 208, 212, 224, 226, 235, 241, 249, 252, 255, 263, 268, 270, 276, 277, 279, 287, 292, 299, 304, 305, 308, 309, 311, 318, 325, 332, 337, 342, 343, 344, 352, 359, 362, 367, 373, 374, 378, 388, 389, 391, 399, 400, 402, 403, 407, 408, 411, 416, 421, 423, 431, 442, 443, 444, 446, 447, 454, 456, 461, 463, 471, 473, 475, 493, 495, 500, 504, 518, 519, 522, 525, 526, 529, 530, 537, 538, 541, 542, 555, 557, 559, 569, 582, 587, 589, 590, 593, 596, 598]
# Test loss: 120.753025
#
# Node 3 analysis completed!

# %% [markdown]
# ### Plot for part A

# %%
results = [
    result1,
    result2,
    result3
]
create_summary_visualizations(results)

# %% [markdown]
# ### Report for part A:

# %% [markdown]
# #### Answer:
# 1. Node 1: Best λ = 232.995181 (Validation loss: 66.887720)
#
#    Node 2: Best λ = 75.431201 (Validation loss: 77.293428)
#
#    Node 3: Best λ = 109.854114 (Validation loss: 33.806052)
#
# 2. Node 1 has 23 Non-zero Coefficients, Node 2 has 130, Node 3 also has 130.
#
#    Node 1 non-zero Coefficients indices: 85, 123, 126, 229, 232, 249, 299, 305, 322, 360, 362, 399, 429, 447, 461, 491, 493, 500, 514, 526, 546, 559, 587
#
#    Node 2 non-zero Coefficients Indices: 3, 4, 6, 8, 14, 18, 26, 34, 35, 36, 40, 52, 61, 65, 71, 77, 78, 80, 90, 92, 93, 94, 97, 98, 104, 109, 111, 116, 117, 118, 123, 125, 130, 135, 144, 148, 153, 165, 173, 182, 204, 206, 210, 212, 218, 223, 227, 231, 237, 249, 266, 268, 269, 281, 285, 289, 294, 299, 302, 304, 305, 306, 307, 311, 315, 321, 324, 329, 333, 345, 350, 351, 356, 360, 362, 369, 391, 399, 400, 411, 412, 413, 423, 425, 430, 431, 440, 442, 443, 445, 447, 457, 461, 470, 471, 473, 474, 475, 479, 491, 492, 493, 500, 503, 509, 519, 521, 524, 526, 537, 538, 539, 541, 545, 547, 550, 552, 558, 559, 566, 569, 576, 577, 578, 581, 583, 584, 587, 589, 594
#
#    Node 3 non-zero Coefficients Indices: 6, 9, 13, 14, 18, 25, 34, 40, 42, 63, 66, 68, 71, 73, 76, 77, 79, 82, 85, 91, 92, 102, 107, 117, 119, 123, 124, 125, 126, 130, 133, 134, 147, 159, 161, 169, 170, 171, 179, 181, 182, 208, 212, 224, 226, 235, 241, 249, 252, 255, 263, 268, 270, 276, 277, 279, 287, 292, 299, 304, 305, 308, 309, 311, 318, 325, 332, 337, 342, 343, 344, 352, 359, 362, 367, 373, 374, 378, 388, 389, 391, 399, 400, 402, 403, 407, 408, 411, 416, 421, 423, 431, 442, 443, 444, 446, 447, 454, 456, 461, 463, 471, 473, 475, 493, 495, 500, 504, 518, 519, 522, 525, 526, 529, 530, 537, 538, 541, 542, 555, 557, 559, 569, 582, 587, 589, 590, 593, 596, 59
#
# 3. 13 coefficients are non-zero across all model. Indices: 123, 249, 299, 305, 362, 399, 447, 461, 493, 500, 526, 559, 587.
#
# 4. Node 1 : Test loss = 83.915862<br>
#    Node 2 : Test loss = 115.740839<br>
#    Node 3 : Test loss = 120.753025<br>

# %% [markdown]
# \newpage
# ## Part B
# ### Aggregator for 5 local ieterations

# %%
from lasso_analysis_runner import run_federated_learning

data_files_list = ['regression_data_node1.csv', 'regression_data_node2.csv', 'regression_data_node3.csv']
test_data_file = 'test_data.csv'

fed_results_5_iter = run_federated_learning(
    data_files_list, test_data_file, 
    local_iterations=5
)
# Out:
# Starting Federated Learning Training (5 local iterations per round)
# Best λ values chosen for each node:
#   Node 1: λ = 232.995181
#   Node 2: λ = 75.431201
#   Node 3: λ = 109.854114
#
# Federated Learning Completed.
# Final Round Status (Round 8):
#   Global test loss: 104.216236
#   Coefficient change: 0.00000097
# Algorithm converged at round 8.
#
# FEDERATED LEARNING RESULTS REPORT
#
# 1. Regularization parameters λ selected by each data node:
#    Node 1: λ = 232.995181
#    Node 2: λ = 75.431201
#    Node 3: λ = 109.854114
#
# 2. Non-zero regression coefficient indices in final aggregated model:
#    Number of non-zero coefficients: 225
# ...

# %% [markdown]
# #### Answer:
# 1. Node 1: λ = 232.995181<br>
#    Node 2: λ = 75.431201<br>
#    Node 3: λ = 109.854114<br>
#
# 2. Number of non-zero coefficients: 225<br>
#    Non-zero coefficient indices:<br>
#   4   6   8   9  13  14  18  25  26  30  34  35  36  40  42
#  46  52  61  63  65  66  68  71  73  76  77  78  79  82  85
#  90  91  92  93  94  97  98 102 104 107 109 117 118 119 120
# 123 124 125 126 130 133 134 135 144 147 148 153 159 161 165
# 169 170 171 173 179 181 182 204 206 208 210 212 218 220 223
# 224 225 226 227 229 231 232 235 237 241 249 252 255 263 266
# 268 269 270 274 276 277 278 279 280 281 287 289 292 299 302
# 304 305 306 307 308 309 311 314 315 316 318 321 322 324 325
# 329 332 333 337 342 343 344 345 350 351 352 356 359 360 362
# 367 369 373 374 378 388 389 391 393 399 400 402 403 407 408
# 411 412 413 416 421 423 425 429 431 440 442 443 444 445 446
# 447 454 456 457 461 463 470 471 473 474 475 479 491 492 493
# 495 500 503 504 509 514 518 519 521 522 524 525 526 529 530
# 537 538 539 541 542 545 546 547 550 552 555 557 558 559 566
# 569 576 577 578 581 582 583 584 587 589 590 593 594 596 598
#
#
# 3. The confusion matrix is shown above in the plot. And Accuracy, Precision and Recall are also given.
#
# 4. The test Loss is 104.216236.
#
# 5. And from these output, we see the accuracy is not very high, especcially in Node 1 vs Global, only 0.6633. But the Recall is 1.0 in all confusion matrix. This model might be good if the data is from some area requiring high precision like medical test.
#
# 6. Slightly Overfitting. From the plot, Global test over Rounds, We see the test loss is increasing slightly, but not severe.

# %% [markdown]
# ### If we use 10 iterations

# %%
fed_results_10_iter = run_federated_learning(
    data_files_list, test_data_file, 
    local_iterations=10
)
# Out:
# Starting Federated Learning Training (10 local iterations per round)
# Best λ values chosen for each node:
#   Node 1: λ = 232.995181
#   Node 2: λ = 75.431201
#   Node 3: λ = 109.854114
#
# Federated Learning Completed.
# Final Round Status (Round 6):
#   Global test loss: 104.181938
#   Coefficient change: 0.00000033
# Algorithm converged at round 6.
#
# FEDERATED LEARNING RESULTS REPORT
#
# 1. Regularization parameters λ selected by each data node:
#    Node 1: λ = 232.995181
#    Node 2: λ = 75.431201
#    Node 3: λ = 109.854114
#
# 2. Non-zero regression coefficient indices in final aggregated model:
#    Number of non-zero coefficients: 223
# ...

# %% [markdown]
# ### Conclusion for aggregator occurs every 10 iterations.
# #### Answer:
# 1. Best lambda are same. These lambda value is selected on tune stage. The aggregator iterations did not affect that.
#
# 2. the non-zero coefficients reduce from 225 to 223. This would not make a large effect on model.
#
# 3. The confusion matrix change slightly. For node 1 and node 2, there is no significant change.
#    But on Node 2 vs Global, the Accuracy increased from 0.8183 to 0.8450, Recall increased from 0.5467 to 0.5830. This is a significant improvement. And all Recall remain 1.
#
# 4. Test loss decreased from 104.216236 to 104.181938. This is approximately equal.
#
# 5. The final model is better than last model using 5 iterations. But the computing cost also increase, even though it converge on less aggregator round, the total computing iteration across all function is increased.
